# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
# %matplotlib inline

# %%
#skill_1 = pd.read_csv('abdulbaqqi.csv')
#skill_1

# %%
wrk1= pd.read_csv('abdulbaqqi_work_experience.csv')
wrk1
# Out:
#         Unnamed: 0                 Job                Name of Organisation  \
# 0  worl experience  Internship Student  Harmony Advanced Diagnostic Centre
#
#   Year of Experience                                            Summary  \
# 0            3months  i worked with the radiographers to know how to...
#
#                         Top Achievement  Objective
# 0  operating some biomedical equipments        NaN

# %%
wrk2= pd.read_csv('Oluwaferanmi_WorkExperience.csv')
wrk2
# Out:
#    Job Title  Years Worked            Achievements
# 0        NaN           NaN  ['Awards upon awards']

# %%
wrk3= pd.read_csv('SamuelWorkExperience.csv')
wrk3
# Out:
#    Unnamed: 0 Position                 Organisation  Year_spent  \
# 0           0  TEACHER  BELVIS INTERNATIONAL SCHOOL           1
#
#   Top_achievement                                       Work_summary  \
# 0            None  Joined after my secondary school, helped in te...
#
#   Work_objective
# 0           None

# %%
wrk4= pd.read_csv('Statesman_work_experience.csv')
wrk4
# Out:
#    Unnamed: 0                              Position Years of Experience  \
# 0           0  ['Research assistant, UPM, 5 years']             5 years
#
#                   Role summary  \
# 0  Perform research activities
#
#                                     Top Achievements  \
# 0  ['Published research that formed basis of a ne...
#
#                              Objective
# 0  To be a versatile Python programmer

# %%
wrk5= pd.read_csv('TheophilusWork Experience.csv')
wrk5
# Out:
#    Unnamed: 0  Job  Years of experience  Work summary  Top Achievements  \
# 0           0  NaN                  NaN           NaN               NaN
#
#                                       Work Objective
# 0  Hoping to be usefulbinthe mahine learning indu...

# %%
wrk6= pd.read_csv('SamuelWorkExperience.csv')
wrk6
# Out:
#    Unnamed: 0 Position                 Organisation  Year_spent  \
# 0           0  TEACHER  BELVIS INTERNATIONAL SCHOOL           1
#
#   Top_achievement                                       Work_summary  \
# 0            None  Joined after my secondary school, helped in te...
#
#   Work_objective
# 0           None

# %%
merge = pd.concat([wrk1,wrk2,wrk3,wrk4,wrk5,wrk6])
merge
# Out:
#              Achievements                 Job  Job Title  \
# 0                     NaN  Internship Student        NaN
# 0  ['Awards upon awards']                 NaN        NaN
# 0                     NaN                 NaN        NaN
# 0                     NaN                 NaN        NaN
# 0                     NaN                 NaN        NaN
# 0                     NaN                 NaN        NaN
#
#                  Name of Organisation                            Objective  \
# 0  Harmony Advanced Diagnostic Centre                                  NaN
# 0                                 NaN                                  NaN
# 0                                 NaN                                  NaN
# 0                                 NaN  To be a versatile Python programmer
# 0                                 NaN                                  NaN
# 0                                 NaN                                  NaN
#
# ...

# %%
merge.drop('Unnamed: 0', axis=1,)
# Out:
#              Achievements                 Job  Job Title  \
# 0                     NaN  Internship Student        NaN
# 0  ['Awards upon awards']                 NaN        NaN
# 0                     NaN                 NaN        NaN
# 0                     NaN                 NaN        NaN
# 0                     NaN                 NaN        NaN
# 0                     NaN                 NaN        NaN
#
#                  Name of Organisation                            Objective  \
# 0  Harmony Advanced Diagnostic Centre                                  NaN
# 0                                 NaN                                  NaN
# 0                                 NaN                                  NaN
# 0                                 NaN  To be a versatile Python programmer
# 0                                 NaN                                  NaN
# 0                                 NaN                                  NaN
#
# ...
